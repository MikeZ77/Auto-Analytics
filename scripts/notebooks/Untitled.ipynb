# %%
auto = read.csv("autotrader.csv")
auto_set = auto[-c(7)]
auto_set$current_year = 2019
auto_set[auto_set$year > 2019,]$year = 2016
#auto_set = auto_set[auto_set$province == 'ON' | auto_set$province == 'QC',]
auto_set$age = auto_set$current_year - auto_set$year
auto_set[auto_set$kilometers == '-',]$kilometers = NA
auto_set = auto_set[auto_set$kilometers != 'NA',]
auto_set$kilometers = gsub(" km", "", auto_set$kilometers)
auto_set$kilometers = as.numeric(gsub(",", "", auto_set$kilometers))

auto_set[auto_set$price > 15000,]
#plot(price~age, data=auto_set)

#plot(price~age, data=auto_set, xlim=c(0,20))

#mod1 = lm(price~age+kilometers+age:kilometers+I(age^2)+I(kilometers^2), data=auto_set)
#summary(mod1)
#plot(mod1)

#density and heatmap
#abline(mod1)
#mod = lm(price~age+I(age^2)+province, data=auto_ON_QC)

#residuals = resid(mod1)
#plot(resid(mod1) ~price, data=auto_set)
#summary(auto_ON_QC$province)
# Out:
#       adID        condition make          model          price    province year
# 4     19-10152856 used      Chevrolet     Corvette       20000    ON       1974
# 23    19-10513770 used      Kia           Sorento        19995    BC       2015
# 24    19-10514978 used      Audi          A6             19999    ON       2013
# 27    19-10538126 used      Pontiac       Firebird       20000    NL       2002
# 30    19-10555860 used      Mercury       M-100          20000    BC       1963
# 31    19-10556197 used      Ford          F-100          20000    BC       1963
# 44    19-10628663 used      Chevrolet     Corvette       20000    SK       1996
# 45    19-10631022 used      Mitsubishi    3000GT         20000    YT       1998
# 49    19-10644101 used      Acura         RDX            19999    AB       2013
# 50    19-10652837 used      Audi          Q5             19995    ON       2013
# 53    19-10662547 used      BMW           1 Series       20000    QC       2012
# ...

# %%
auto_set[879,]
auto_set[3269,]
auto_set[4904,]
auto_set[6388,]
auto_set[2812,]
# Out:
#     adID        condition make model  price province year kilometers
# 879 19-11065120 used      Ford Fusion 10000 NS       2014 88000600
#     exterior_color fuel_type current_year age
# 879 black          gasoline  2019         5
#      adID        condition make model price province year kilometers
# 3269 19-11126087 used      Fiat 500   9125  ON       2013 7171794
#      exterior_color fuel_type current_year age
# 3269 black          gasoline  2019         6
#      adID        condition make    model   price province year kilometers
# 4904 19-11139895 used      Mercury Monarch 9500  BC       1956 1e+06
#      exterior_color fuel_type current_year age
# 4904 -              -         2019         63
#      adID        condition make model   price province year kilometers
# 6388 19-11146086 used      Ford Model T 10000 ON       1926 100
#      exterior_color fuel_type current_year age
# 6388 -              gasoline  2019         93
# ...
